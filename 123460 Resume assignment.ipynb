# %% [markdown]
# # Resume Parsing
#
# So basically, we want to create a entity ruler to parse real resume and get the "skills".
#
# But for your assignment, i will ask you to extract education.

# %% [markdown]
# ## 1. Load data

# %%
import pandas as pd
import numpy as np

df_resume = pd.read_csv("resume.csv")

# %%
df_resume = df_resume.reindex(np.random.permutation(df_resume.index))
df_resume = df_resume.copy().iloc[:1000, ]  #optional if your computer is fast, no need
df_resume.shape
# Out:
# (1000, 4)

# %% [markdown]
# ## 2. Load skill data
#
# If we define patterns for all the skill, we gonna be too tired.
#
# So spacy knows that, so it allows you to give you a list of words, then it will automatically create pattern.

# %%
import spacy

nlp = spacy.load('en_core_web_md')
skill_path = "skills.jsonl"

# %%
ruler = nlp.add_pipe("entity_ruler")
ruler.from_disk(skill_path)
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner',
#  'entity_ruler']

# %%
doc = nlp("Chaky loves deep learning.")
doc.ents
# Out:
# (Chaky, deep learning)

# %% [markdown]
# ## 3. Let's try to extract skills from this resume.csv

# %%
df_resume.head()
# Out:
#             ID                                         Resume_str  \
# 2152  24580361           ASSOCIATE, INVESTMENT BANKING OPERATI...
# 1969  15721849           CONSTRUCTION PROJECT REGIONAL MANAGER...
# 1670  14304010           KEY HOLDER, SALES PLANNER       Summa...
# 1737  55595908           SITE ENGINEERING           Career Ove...
# 1606  56151548           SUBSTITUTE TEACHER           Summary ...
#
#                                             Resume_html      Category
# 2152  <div class="fontsize fontface vmargins hmargin...       BANKING
# 1969  <div class="fontsize fontface vmargins hmargin...  CONSTRUCTION
# 1670  <div class="fontsize fontface vmargins hmargin...       APPAREL
# 1737  <div class="fontsize fontface vmargins hmargin...   ENGINEERING
# 1606  <div class="fontsize fontface vmargins hmargin...       APPAREL

# %%
from spacy.lang.en.stop_words import STOP_WORDS

#before that, let's clean our resume.csv dataframe
def preprocessing(sentence):
    
    stopwords = list(STOP_WORDS)
    doc = nlp(sentence)
    cleaned_tokens = []
    
    for token in doc:
        if token.text not in stopwords and token.pos_ != 'PUNCT' and token.pos_ != 'SPACE' and \
            token.pos_ != 'SYM':
                cleaned_tokens.append(token.lemma_.lower().strip())
                
    return " ".join(cleaned_tokens)

# %%
#let's try Chaky, if you feel too dangerous
#random sampling
random_resume = df_resume.Resume_str.iloc[5]
random_resume[:300]
# Out:
# "         MORTGAGE BANKING RESEARCH SPECIALIST       Summary    My goal is to obtain a career associated with a company where I can utilize my skills and gain further experience while enhancing the company's brand and reputation.      Highlights          5+ years of Leadership as a  Supervisor/Manage"

# %%
preprocessing(random_resume[:300])
# Out:
# 'mortgage banking research specialist summary my goal obtain career associate company i utilize skill gain experience enhance company brand reputation highlight 5 + year leadership supervisor manage'

# %%
#let's apply to the whole dataframe
for i, row in df_resume.iterrows():
    clean_text = preprocessing(row.Resume_str)
    df_resume.at[i, 'Clean_resume'] = clean_text

# %%
df_resume.head()
# Out:
#             ID                                         Resume_str  \
# 2152  24580361           ASSOCIATE, INVESTMENT BANKING OPERATI...
# 1969  15721849           CONSTRUCTION PROJECT REGIONAL MANAGER...
# 1670  14304010           KEY HOLDER, SALES PLANNER       Summa...
# 1737  55595908           SITE ENGINEERING           Career Ove...
# 1606  56151548           SUBSTITUTE TEACHER           Summary ...
#
#                                             Resume_html      Category  \
# 2152  <div class="fontsize fontface vmargins hmargin...       BANKING
# 1969  <div class="fontsize fontface vmargins hmargin...  CONSTRUCTION
# 1670  <div class="fontsize fontface vmargins hmargin...       APPAREL
# 1737  <div class="fontsize fontface vmargins hmargin...   ENGINEERING
# 1606  <div class="fontsize fontface vmargins hmargin...       APPAREL
#
#                                            Clean_resume
# 2152  associate investment banking operation highlig...
# 1969  construction project regional manager summary ...
# 1670  key holder sales planner summary art director ...
# 1737  site engineering career overview 10 + year tot...
# 1606  substitute teacher summary seek administrative...

# %% [markdown]
# ## 4. Let's really extract skills!!

# %%
def get_skills(text):
    #pass the text to the nlp
    doc = nlp(text)  #note that this nlp already know skills
    
    skills = []
    
    #look at the ents
    for ent in doc.ents:
        #if the ent.label_ is SKILL, then we append to some list
        if ent.label_ == "SKILL":
            skills.append(ent.text)
    
    return skills

def unique_skills(x):
    return list(set(x))

# %%
df_resume.head(3)
# Out:
#             ID                                         Resume_str  \
# 2152  24580361           ASSOCIATE, INVESTMENT BANKING OPERATI...
# 1969  15721849           CONSTRUCTION PROJECT REGIONAL MANAGER...
# 1670  14304010           KEY HOLDER, SALES PLANNER       Summa...
#
#                                             Resume_html      Category  \
# 2152  <div class="fontsize fontface vmargins hmargin...       BANKING
# 1969  <div class="fontsize fontface vmargins hmargin...  CONSTRUCTION
# 1670  <div class="fontsize fontface vmargins hmargin...       APPAREL
#
#                                            Clean_resume
# 2152  associate investment banking operation highlig...
# 1969  construction project regional manager summary ...
# 1670  key holder sales planner summary art director ...

# %%
df_resume['Skills'] = df_resume.Clean_resume.apply(get_skills)
df_resume['Skills'] = df_resume.Skills.apply(unique_skills)

# %%
df_resume.Skills.iloc[0]
# Out:
# ['operations management', 'database', 'business']

# %% [markdown]
# ## 5. Visualization
# ​
# Which skills is most important in information management?

# %%
set(df_resume.Category)
# Out:
# {'ACCOUNTANT',
#  'ADVOCATE',
#  'AGRICULTURE',
#  'APPAREL',
#  'ARTS',
#  'AUTOMOBILE',
#  'AVIATION',
#  'BANKING',
#  'BPO',
#  'BUSINESS-DEVELOPMENT',
#  'CHEF',
#  'CONSTRUCTION',
#  'CONSULTANT',
#  'DESIGNER',
#  'DIGITAL-MEDIA',
#  'ENGINEERING',
#  'FINANCE',
#  'FITNESS',
#  'HEALTHCARE',
#  'HR',
#  'INFORMATION-TECHNOLOGY',
#  'PUBLIC-RELATIONS',
#  'SALES',
#  'TEACHER'}

# %%
category = 'INFORMATION-TECHNOLOGY'
cond = df_resume.Category == category

df_resume_it = df_resume[cond]
df_resume_it.shape
# Out:
# (50, 6)

# %%
all_skill = np.concatenate(df_resume_it.Skills.values)

# %%
#counting
from collections import Counter, OrderedDict

counting = Counter(all_skill)
counting = OrderedDict(counting.most_common(10))

# %%
counting
# Out:
# OrderedDict([('support', 46),
#              ('software', 42),
#              ('security', 35),
#              ('business', 34),
#              ('design', 32),
#              ('database', 29),
#              ('windows', 27),
#              ('project management', 26),
#              ('server', 25),
#              ('documentation', 19)])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 3))
plt.xticks(rotation =45)

plt.bar(counting.keys(), counting.values())
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## 6. Name Entity Recognition

# %%
from spacy import displacy

text = df_resume_it.Clean_resume.iloc[43]

# %%
doc = nlp(text)

# %%
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner',
#  'entity_ruler']

# %%
colors = {"SKILL": "linear-gradient(90deg, #aa9cfc, #fc9ce7)"}
options = {"colors": colors}

displacy.render(doc, style="ent", options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">information technology specialist summary information
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     security
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  analyst systems professional
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16 year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  diverse experience analysis troubleshooting management
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     testing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  complex it system experience include analytical
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     support
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  computer surveillance activity cyber
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     security
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  intrusion detection analysis system administration also knowledgeable military cyber operations
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     security
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  clearance currently hold active ts sci
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     security
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  clearance last update
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2013
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  technical skills qualifications
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     windows
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  unix
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     linux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  vmware wireshark snort tcpdump encase
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  programming configure
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     router
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  switch computer networking intrusion analysis firewall work experience information technology specialist 05/2009
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     －
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  current company name
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     － city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  state provide electronic surveillance information system perform digital evidence analysis dea provide technical analytical
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     support
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  computer surveillance activity ​provide traffic analysis adversary ttp tactic technique protocol configure install
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     router
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  switch
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wireless
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  controller draft training
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     material
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  organize training session
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  employee
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     network security
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  analyst
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     08/2008 －
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  05/2009 company name
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em;

# %% [markdown]
# ## 7. Let's load the PDF - add some realism

# %%
from PyPDF2 import PdfReader
#pip install PyPDF2

reader = PdfReader("someone_cv.pdf")
page = reader.pages[0] #first page just for demo
text = page.extract_text()

# %%
text = preprocessing(text)

# %%
doc = nlp(text)

# %%
colors = {"SKILL": "linear-gradient(90deg, #aa9cfc, #fc9ce7)"}
options = {"colors": colors}

displacy.render(doc, style="ent", options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">y
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oshua bengio c.v département d’informatique et recherche opérationnelle université de montréal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  phone
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     514
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  - 343
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6804
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  yoshua.bengio@mila.quebec
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     https://mila.quebec/en/yoshua- bengio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  a.m. turing award fellow royal society
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     london
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  fellow
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     royal society canada cifar ai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chair titles distinctions
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     full
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  professor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     université de montréal department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     computer science
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  operation research
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2002
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  recruit assistant prof
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1993
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  previously associate professor
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1997 2002
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  assistant professor
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1993 1997
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  research chair onstatistical learning
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     algorithms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2001 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  recipient
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cifar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ccai chair
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018 2023 1.25m$ recipient 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  a.m. turing award
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  killam prize
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     victorin québec prize
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  high distinction science province
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     québec prix d’excellence du frqnt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVEN

# %%
#last thing i go to assignment
#collect all the skill and put it into a list

skills = []

for ent in doc.ents:
    if ent.label_ == 'SKILL':
        skills.append(ent.text)
        
print(set(skills))
# Out:
# {'algorithms', 'computer science', 'engineering', 'ai', 'deep learning'}

# %% [markdown]
# # Assignment
#
# I can't create an web-app because of installing problems, then I can do an assignment by csv. instead. sorry for doing imcomplete assignment.

# %%
# convert all files into .csv file
# create dataframe from all labels
import csv
  
field_names = ['No', 'Company', 'Car Model']

label = []
resume_dct = {}
for ent in doc.ents:
    if ent.label_ not in label:
        label.append(ent.label_)
        resume_dct[ent.label_] = []
        resume_dct[ent.label_].append(ent.text)
    else:
        resume_dct[ent.label_].append(ent.text)
print(resume_dct)
row = []
with open('resume.csv', 'w+') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames = label)
    writer.writeheader()
    for key in label:
        for val in resume_dct[key]:
            row.append({key:val})
    writer.writerows(row)
df_resume = pd.read_csv('resume.csv')
df_resume = df_resume.apply(lambda x : sorted(x,key=pd.isnull))
df_resume.to_csv('resume.csv') 
df_resume.head()
# Out:
# {'ORG': ['oshua bengio c.v département d’informatique et recherche opérationnelle université de montréal', 'royal society canada cifar ai', '\x0ffull', 'cifar', 'ccai chair', 'ministry inter- national relations francophonie', 'intelligence institute montreal institute', 'gan', 'ado data v alorization institute', 'cfref'], 'CARDINAL': ['514', '300', '35', '93.6m$'], 'DATE': ['6804', '2002', '1993', '1997 2002', '1993 1997', '2001 2019', '2018 2023 1.25m$ \x0frecipient 2018', '2019', '2017', '2019', '2018 2019', '2009', '2017', '2018', '2006', '2009', '2011', '2014', '2016 2023'], 'PERSON': ['https://mila.quebec/en/yoshua- bengio', 'université de montréal department', 'victorin québec prize', 'acfas urgel archambault', 'mila quebec', 'u. montréal hec', 'montreal mcgill', 'mila'], 'GPE': ['london'], 'SKILL': ['computer science', 'algorithms', 'ai', 'computer science', 'engineering', 'ai', 'algorithms', 'ai', 'deep learning', 'deep learning', 'deep learning'], 'NORP': ['\x0fcanada', 'canadian', 'canadians'], 'EVENT': ['québec prix d’excellence du frqnt'], 'ORDINAL': ['50th']}
#                                                  ORG CARDINAL       DATE  \
# 0  oshua bengio c.v département d’informatique et...      514       6804
# 1                      royal society canada cifar ai      300       2002
# 2                                              full       35       1993
# 3                                              cifar   93.6m$  1997 2002
# 4                                         ccai chair      NaN  1993 1997
#
#                                   PERSON     GPE             SKILL       NORP  \
# 0  https://mila.quebec/en/yoshua- bengio  london  computer science    canada
# 1      université de montréal department     NaN        algorithms   canadian
# 2                  victorin québec prize     NaN                ai  canadians
# 3                acfas urgel archambault     NaN  computer science        NaN
# 4                            mila quebec     NaN       engineering        NaN
#
#                                EVENT ORDINAL
# 0  québec prix d’excellence du frqnt    50th
# 1                                NaN     NaN
# 2                                NaN     NaN
# 3                                NaN     NaN
# 4                                NaN     NaN
